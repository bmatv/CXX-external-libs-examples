# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
array = pd.read_csv("example.txt",delim_whitespace=True,header=None).values
# Out:
# /tmp/ipykernel_31594/3707693039.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   array = pd.read_csv("example.txt",delim_whitespace=True,header=None).values

# %%
fig, ax = plt.subplots(figsize=(5,30
                                ))

ax.axes.imshow(array)

# %%
array2 = array.copy()#.flatten()
fig, ax = plt.subplots(figsize=(5,30
                                ))
array2[array2 < 1050] = 0
ax.axes.imshow(array2)
