# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
array = pd.read_csv("build/example.txt",delim_whitespace=True,header=None).values
# Out:
# /tmp/ipykernel_17710/2436150955.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   array = pd.read_csv("build/example.txt",delim_whitespace=True,header=None).values

# %%
fig, ax = plt.subplots(figsize=(5,30
                                ))

ax.axes.imshow(array)

maxValCoords = np.argwhere(array == array.max())[0]
print(maxValCoords)
ax.scatter(maxValCoords[1],maxValCoords[0])
# Out:
# [57 63]

# %%
edges_array = pd.read_csv("output_edges.txt",delim_whitespace=True,header=None).values
# Out:
# /tmp/ipykernel_232987/2519517731.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   edges_array = pd.read_csv("output_edges.txt",delim_whitespace=True,header=None).values

# %%
(edges_array!=0).sum()
# Out:
# np.int64(16930)

# %%
plt.imshow(edges_array)

# %%
fig, ax = plt.subplots(figsize=(5,30
                                ))

ax.axes.imshow(array)

# %%
array2 = array.copy()#.flatten()
fig, ax = plt.subplots(figsize=(5,30
                                ))
array2[array2 < 15000] = 0
ax.axes.imshow(array2)
