# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import netCDF4 as nc

# %%
path2mangofile = "/home/bogdanm/data/containerSamples/Whiting_5640_5mm_031114_preserved/tomoLoRes_SStomDataInputDump.nc"

tomoAvg = nc.Dataset(path2mangofile)
plt.imshow(tomoAvg['tomo'][99].data)

# %%
plt.plot(tomoAvg['tomo'][99].data[600,:])

# %%
path2mangofile = "/home/bogdanm/data/containerSamples/Whiting_5640_5mm_031114_preserved/tomo_floatLoRes_SStomDataAvg.nc"

tomoAvg = nc.Dataset(path2mangofile)
plt.imshow(tomoAvg['tomo_float'][99].data)

# %%
plt.plot(tomoAvg['tomo_float'][99].data[:,400])

# %%
tomoAvg['tomo_float'][:].max()

# %%
path2mangofile = "/home/bogdanm/data/containerSamples/Whiting_5640_5mm_031114_preserved/tomoLoRes_SStomDataAvg.nc"

tomoAvg = nc.Dataset(path2mangofile)
plt.imshow(tomoAvg['tomo'][99].data)

# %%
plt.plot(tomoAvg['tomo'][99].data[:,400].astype(np.uint16))

# %%
path2mangofile = "/home/bogdanm/data/containerSamples/Whiting_5640_5mm_031114_preserved/tomo_floatLoRes_SStomDataEdges.nc"
tomoProcessed = nc.Dataset(path2mangofile)
plt.imshow(tomoProcessed['tomo_float'][99].data)

# %%
path2mangofile = "/home/bogdanm/data/containerSamples/Whiting_5640_5mm_031114_preserved/tomo_floatLoRes_SStomDataAvg.nc"
tomoProcessed = nc.Dataset(path2mangofile)
plt.imshow(tomoProcessed['tomo_float'][0].data)

# %%
path2mangofile = "/home/bogdanm/data/containerSamples/Whiting_5640_5mm_031114_preserved/tomo_floatLoRes_SStomDataEdgesFilt.nc"
tomoProcessed = nc.Dataset(path2mangofile)
print((tomoProcessed['tomo_float'][0].data!=0).sum())
plt.imshow(tomoProcessed['tomo_float'][0].data)

# %%
path2mangofile = "/home/bogdanm/data/containerSamples/Whiting_5640_5mm_031114_preserved/tomo_floatLoRes_SStomDataEdgesGrdFilt.nc"
tomoProcessed = nc.Dataset(path2mangofile)
print((tomoProcessed['tomo_float'][0].data!=0).sum())

fig, ax = plt.subplots(figsize=(5,5))
ax.axes.imshow(tomoProcessed['tomo_float'][0].data)

ax.scatter(322,302,color='r',marker='+')
circ1 = plt.Circle((322,302),280,fill=False,color='r')
ax.add_patch(circ1)

# %%
plt.imshow(tomoProcessed['tomo_float'][0].data - tomoProcessed['tomo_float'][90].data)

# %%
path2mangofile = "/home/bogdanm/data/containerSamples/RSES_Wood_PigTeeth_3rdMolars/tomo_floatLoRes_SStomDataEdgesGrdFilt.nc"
tomoProcessed = nc.Dataset(path2mangofile)
fig, ax = plt.subplots(figsize=(10,10))
ax.axes.imshow(tomoProcessed['tomo_float'][0].data)

ax.scatter(331,343,color='r',marker='+')
ax.scatter(339,343,color='w',marker='+')
circ1 = plt.Circle((331,343),304,fill=False,color='r')
circ2 = plt.Circle((339,343),312,fill=False,color='w')

circ3 = plt.Circle((331,343),320,fill=False,color='orange')
ax.add_patch(circ1)
ax.add_patch(circ2)
ax.add_patch(circ3)

# %%
path2mangofile = "/home/bogdanm/data/containerSamples/RSES_Wood_PigTeeth_3rdMolars/tomo_floatLoRes_SStomDataEdgesGrdFilt.nc"
tomoProcessed = nc.Dataset(path2mangofile)
plt.imshow(tomoProcessed['tomo_float'][85].data)

# %%
plt.imshow(tomoProcessed['tomo_float'][0].data - tomoProcessed['tomo_float'][85].data)

# %%
path = "/home/bogdanm/Projects/qmango/install/bin/example.txt"
arr = pd.read_csv(path,header=None,delim_whitespace=True).values

fig,ax = plt.subplots(figsize=(10,10))
ax.axes.imshow(arr)
# Out:
# /tmp/ipykernel_3167/2158669342.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   arr = pd.read_csv(path,header=None,delim_whitespace=True).values

# %%
path = "/home/bogdanm/Projects/qmango/install/bin/example2.txt"
arr = pd.read_csv(path,header=None,delim_whitespace=True).values

fig,ax = plt.subplots(figsize=(10,10))
ax.axes.imshow(arr)
# Out:
# /tmp/ipykernel_3167/2959148612.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   arr = pd.read_csv(path,header=None,delim_whitespace=True).values

# %%
17966 // (630*630)

# %%
(17966 % (630*630)) // 630 # y index, div by nx

# %%
17966 % 630 # this is x index

# %%
arr

# %%
arr

# %%
arr_r = arr.reshape((5,128,128))

((arr_r[0] - arr_r[4])!=0).sum()

# %%
path = "/home/bogdanm/Projects/qmango/install/bin/example.txt"
arr = pd.read_csv(path,header=None,delim_whitespace=True).values

fig,ax = plt.subplots(figsize=(5,10))
ax.axes.imshow(arr)

# %%
arr.shape

# %%
plt.plot(tomoProcessed['tomo_float'][0].data[400])

# %%
630*630*100

# %%
plt.plot(tomoProcessed['tomo_float'][99].data[400])

# %%
tomoSubSet = nc.Dataset('/home/bogdanm/data/containerSamples/Whiting_5640_5mm_031114_preserved/tomoLoRes_SS.nc')

# %%
tomoData = tomoSubSet['tomo']

# %%
data = tomoData[:].data.astype(np.uint16)

# %%
data.sum()

# 395351898135 is the value from the test filter. It works!!!

# %%
data[20]

# %%
plt.imshow(data[20])

# %%
plt.imshow(data[20])

# %%
array = pd.read_csv("build/example.txt",sep='\s+',header=None).values

# 128x128, scal 4

fig, ax = plt.subplots(figsize=(3,15))

ax.axes.imshow(array)

maxValCoords = np.argwhere(array == array.max())[0]
print(maxValCoords)
ax.scatter(maxValCoords[1],maxValCoords[0])

# %%
array = pd.read_csv("build/example2.txt",delim_whitespace=True,header=None).values

fig, ax = plt.subplots()

ax.axes.imshow(array)

maxValCoords = np.argwhere(array == array.max())[0]
print(maxValCoords)
ax.scatter(maxValCoords[1],maxValCoords[0],color='r',marker='+')


# MaxVal: 2213; MaxValIdx: 2676
# Radius: 1210; iIdx: 19; jIdx: 20
# xAbs: 1331; yAbs: 1386
# Outputting the accumulator (Iteration I)

# Radii assessed:
# 1209.5 1209.75 1210 1210.25 1210.5 
# MaxVal: 847; MaxValIdx: 1651
# Radius: 1209.75; iIdx: 19; jIdx: 19
# xAbs: 1334; yAbs: 1389
# Outputting the accumulator (Iteration II)

# %%
edges_array = pd.read_csv("build/output_edges.txt",delim_whitespace=True,header=None).values

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.axes.imshow(edges_array,cmap='terrain')

# %%
(edges_array!=0).sum()

# %%
(edges_array!=0).sum()

# %%
edges_array.mean()
