# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
array = pd.read_csv("example.txt",delim_whitespace=True,header=None).values
# Out:
# /tmp/ipykernel_23227/3707693039.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   array = pd.read_csv("example.txt",delim_whitespace=True,header=None).values

# %%
fig, ax = plt.subplots(figsize=(5,30
                                ))

ax.axes.imshow(array)

maxValCoords = np.argwhere(array == array.max())[0]
print(maxValCoords)
ax.scatter(maxValCoords[1],maxValCoords[0])
# Out:
# [377  41]

# %%
edges_array = pd.read_csv("output_edges.txt",delim_whitespace=True,header=None).values
# Out:
# /tmp/ipykernel_23227/2519517731.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   edges_array = pd.read_csv("output_edges.txt",delim_whitespace=True,header=None).values

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.axes.imshow(edges_array,cmap='terrain')

# %%
(edges_array!=0).sum()
# Out:
# np.int64(16930)

# %%
edges_array.mean()
# Out:
# np.float64(20.217851740365333)
