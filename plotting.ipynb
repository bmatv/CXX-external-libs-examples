# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
array = pd.read_csv("build/example.txt",delim_whitespace=True,header=None).values
# Out:
# /tmp/ipykernel_31594/2436150955.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   array = pd.read_csv("build/example.txt",delim_whitespace=True,header=None).values

# %%
fig, ax = plt.subplots(figsize=(5,30
                                ))

ax.axes.imshow(array)
