# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
array = pd.read_csv("build/example.txt",delim_whitespace=True,header=None).values
# Out:
# /tmp/ipykernel_25714/2436150955.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   array = pd.read_csv("build/example.txt",delim_whitespace=True,header=None).values

# %%
# 128x128, scal 4

fig, ax = plt.subplots()

ax.axes.imshow(array)

maxValCoords = np.argwhere(array == array.max())[0]
print(maxValCoords)
ax.scatter(maxValCoords[1],maxValCoords[0])
# Out:
# [200  86]

# %%
fig, ax = plt.subplots()

ax.axes.imshow(array)

maxValCoords = np.argwhere(array == array.max())[0]
print(maxValCoords)
ax.scatter(maxValCoords[1],maxValCoords[0])
# Out:
# [100  42]

# %%
edges_array = pd.read_csv("build/output_edges.txt",delim_whitespace=True,header=None).values
# Out:
# /tmp/ipykernel_93968/2989740319.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   edges_array = pd.read_csv("build/output_edges.txt",delim_whitespace=True,header=None).values

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.axes.imshow(edges_array,cmap='terrain')

# %%
(edges_array!=0).sum()
# Out:
# np.int64(16930)

# %%
(edges_array!=0).sum()
# Out:
# np.int64(158461)

# %%
edges_array.mean()
# Out:
# np.float64(20.217851740365333)
